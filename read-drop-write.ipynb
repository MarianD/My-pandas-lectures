# %%
import pandas as pd

# %%
df = pd.read_csv("1000 Sales Records.csv")
df.sample(5)
# Out:
#                     Region                Country  Item Type Sales Channel  \
# 402     Sub-Saharan Africa                 Malawi  Cosmetics       Offline
# 608     Sub-Saharan Africa              Swaziland  Baby Food       Offline
# 642  Australia and Oceania        Solomon Islands    Clothes       Offline
# 4       Sub-Saharan Africa                   Chad     Fruits       Offline
# 528     Sub-Saharan Africa  Republic of the Congo     Fruits        Online
#
#     Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 402              H  6/20/2017  674421346  6/29/2017        5118      437.20
# 608              M  9/25/2013  151807725  9/29/2013        2134      255.28
# 642              M   8/9/2014  647278249  9/16/2014        2873      109.28
# 4                H  8/16/2011  645713555  8/31/2011        9845        9.33
# 528              L  4/30/2012  251529252   5/5/2012        1950        9.33
#
#      Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.drop(columns=[name for name in df.columns if name.startswith("Total") ], inplace=True)
df.sample(5)
# Out:
#                  Region                   Country        Item Type  \
# 377  Sub-Saharan Africa     Sao Tome and Principe             Meat
# 79        North America  United States of America  Office Supplies
# 287              Europe                  Slovakia       Vegetables
# 69               Europe                   Austria  Office Supplies
# 736              Europe               Switzerland             Meat
#
#     Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 377       Offline              M   3/28/2014  386163699  4/19/2014
# 79         Online              C    6/9/2017  811701095  7/19/2017
# 287        Online              M   4/24/2016  769822585  5/15/2016
# 69         Online              L   5/12/2011  285341823   6/8/2011
# 736        Online              C  12/22/2012  703815782   1/7/2013
#
#      Units Sold  Unit Price  Unit Cost
# 377        3275      421.89     364.69
# 79         9247      651.21     524.96
# ...

# %%
df.to_csv("1000 objednavok.csv", index=False)
